# %%
import requests
import json
import logging
import re

# %%
def bilibili_headers(referer=None, cookie=None):
        # 请求消息的头部，模拟浏览器的行为访问Bilibili网站，否则访问会被拒绝
        ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.84 Safari/537.36'
        headers = {'User-Agent': ua}
        if referer is not None:
            headers.update({'Referer': referer})
        if cookie is not None:
            headers.update({'Cookie': cookie})
        return headers

# %%
def get_content(url, headers={}, decoded=True):
        # 获取链接的html文件
        logging.debug('get_content: %s' % url)
        data = None
        session = requests.Session()
        try:
            response = session.get(url, headers=headers,verify=False)
        except:
            raise
        else:
            data = response.text
        return data

# %%
def match1(text, *patterns):
    """Scans through a string for substrings matched some patterns (first-subgroups only).

    Args:
        text: A string to be scanned.
        patterns: Arbitrary number of regex patterns.

    Returns:
        When only one pattern is given, returns a string (None if no match found).
        When more than one pattern are given, returns a list of strings ([] if no match found).
    """

    if len(patterns) == 1:
        pattern = patterns[0]
        match = re.search(pattern, text)
        if match:
            return match.group(1)
        else:
            return None
    else:
        ret = []
        for pattern in patterns:
            match = re.search(pattern, text)
            if match:
                ret.append(match.group(1))
        return ret

# %%
stream_types = [
        {'id': 'flv_p60', 'quality': 116, 'audio_quality': 30280,
         'container': 'FLV', 'video_resolution': '1080p', 'desc': '高清 1080P60'},
        # 'id': 'hdflv2', 'quality': 112?
        {'id': 'flv', 'quality': 80, 'audio_quality': 30280,
         'container': 'FLV', 'video_resolution': '1080p', 'desc': '高清 1080P'},
        {'id': 'flv720_p60', 'quality': 74, 'audio_quality': 30280,
         'container': 'FLV', 'video_resolution': '720p', 'desc': '高清 720P60'},
        {'id': 'flv720', 'quality': 64, 'audio_quality': 30280,
         'container': 'FLV', 'video_resolution': '720p', 'desc': '高清 720P'},
        {'id': 'hdmp4', 'quality': 48, 'audio_quality': 30280,
         'container': 'MP4', 'video_resolution': '720p', 'desc': '高清 720P (MP4)'},
        {'id': 'flv480', 'quality': 32, 'audio_quality': 30280,
         'container': 'FLV', 'video_resolution': '480p', 'desc': '清晰 480P'},
        {'id': 'flv360', 'quality': 16, 'audio_quality': 30216,
         'container': 'FLV', 'video_resolution': '360p', 'desc': '流畅 360P'},
        # 'quality': 15?
        {'id': 'mp4', 'quality': 0},
    ]

# %%
stream_qualities = {s['quality']: s for s in stream_types}
stream_qualities
# Out:
# {0: {'id': 'mp4', 'quality': 0},
#  16: {'audio_quality': 30216,
#   'container': 'FLV',
#   'desc': '流畅 360P',
#   'id': 'flv360',
#   'quality': 16,
#   'video_resolution': '360p'},
#  32: {'audio_quality': 30280,
#   'container': 'FLV',
#   'desc': '清晰 480P',
#   'id': 'flv480',
#   'quality': 32,
#   'video_resolution': '480p'},
#  48: {'audio_quality': 30280,
#   'container': 'MP4',
#   'desc': '高清 720P (MP4)',
#   'id': 'hdmp4',
#   'quality': 48,
#   'video_resolution': '720p'},
#  64: {'audio_quality': 30280,
#   'container': 'FLV',
#   'desc': '高清 720P',
#   'id': 'flv720',
#   'quality': 64,
#   'video_resolution': '720p'},
#  74: {'audio_quality': 30280,
#   'container': 'FLV',
#   'desc': '高清 720P60',
#   'id': 'flv720_p60',
#   'quality': 74,
#   'video_resolution': '720p'},
#  80: {'audio_quality': 30280,
#   'container': 'FLV',
#   'desc': '高清 1080P',
#   'id': 'flv',
#   'quality': 80,
#   'video_resolution': '1080p'},
#  116: {'audio_quality': 30280,
#   'container': 'FLV',
#   'desc': '高清 1080P60',
#   'id': 'flv_p60',
#   'quality': 116,
#   'video_resolution': '1080p'}}

# %%
#https://www.bilibili.com/video/av29306544
# https://www.bilibili.com/video/av30080993
url = "https://www.bilibili.com/video/av29306544"
html_content = get_content(url, headers=bilibili_headers())
html_content
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:794: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# '<!DOCTYPE html><html><head itemprop="video" itemscope itemtype="http://schema.org/VideoObject"><title data-vue-meta="true">【尚学堂】Java300集2019版--高淇_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili</title> <meta data-vue-meta="true" http-equiv="Content-Type" content="text/html" charset="utf-8"><meta data-vue-meta="true" name="renderer" content="webkit"><meta data-vue-meta="true" http-equiv="X-UA-Compatible" content="IE=edge"><meta data-vue-meta="true" name="spm_prefix" content="333.788"><meta data-vue-meta="true" itemprop="keywords" name="keywords" content="【尚学堂】Java300集2019版--高淇,JAVA,程序员,公开课,教育,考试,学习,视频教程,课程,编程,线上课堂,科技,演讲·公开课,哔哩哔哩,Bilibili,B站,弹幕"><meta data-vue-meta="true" itemprop="description" name="description" content="关注订阅号「码匠笔记」回复「源码」获取 源码+课件"><meta data-vue-meta="true" itemprop="author" name="author" content="哇哈是鸡肉味"><meta data-vue-meta="true" itemprop="name" name="title" content="【尚学堂】Java300集2019版--高淇_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili"><meta data-vue-meta="true" itemprop="url" content="https://www.bilibili.com/video/av29306544/"><meta data-vue-meta="true" itemprop="image" content="http://i2.hdslb.com/bfs/archive/8692211e9a756bab2ec31086679ae7664ff1c82b.jpg"><meta data-vue-meta="true" itemprop="thumbnailUrl" content="http://i2.hdslb.com/bfs/archive/8692211e9a756bab2ec31086679ae7664ff1c82b.jpg"><meta data-vue-meta="true" itemprop="uploadDate" content="2018-08-14 10:12:26"><meta data-vue-meta="true" itemprop="datePublished" content="2018-08-14 10:12:25"><meta data-vue-meta="true" itemprop="comment" content="一起打卡学习~00，《Java 编程学习第一季》：av4710378100，《Java 企业开发第一季 - Spring 实战》：av4717683200，《Java 企业开发第二季 - MyBatis 实战》：av4722883000，《Java 企业开发第三季 - Spring MVC 实战》：av4721856600，《Java 企业开发第四季 - Spring Boot 实战》：av4723013700，《Java 企业开发第五季 - Spring Cloud 实战》：00，《Java 企业开发第六季 - Dubbo 实战》：av4700914300，《Java 企业开发第七季 - 电商项目实战》：av4830845300，《数据库第一季 - MySQL 实战》：av4770290500，《数据库第二季 - Redis 实战》：av4742317400，《数据库第三季 - MongoDB 实战》：av4742535200，《数据库第四季 - Elasticsearch 实战》：av4827998900，《数据库第五季 - Oracle 实战》：av4850247300，《前端开发第一季 - HTML + CSS 实战》：av4912664900，《前端开发第二季 - Javascript 实战》：av4892731300，《前端开发第三季 - React 实战》：av4803369500，《前端开发第四季 - Vue 实战》：av5088689100，《前端开发第五季 - React 项目实战》：av4849506600，《前端开发第六季 - Vue 项目实战》：av4833347700，《大数据开发第一季 - Hadoop》：av4862176900，《大数据开发第二季 - HBase》：av4858179200，《大数据开发第三季 - Hive》：av4860942700，《大数据开发第四季 - Flink》：av5099636700，《大数据开发第五季 - Spark》：av4866807900，《架构之路第一季 - RabbitMQ》：av4844426200，《架构之路第二季 - Kafka》：av4777399000，《架构之路第三季 - Zookeeper》：av47773419,飞机爆炸效果图链接：http://www.sxt.cn/Java_jQuery_in_action/thirteen-explosioneffect.html,第一天学习java！加油！争取看到60集。大一还没上课发现同学一个个都会很多编程知识，瑟瑟发抖，国庆疯狂补课。"><meta data-vue-meta="true" itemprop="commentCount" content="1396"><meta data-vue-meta="true" property="og:type" content="video"><meta data-vue-meta="true" property="og:title" content="【尚学堂】Java300集2019版--高淇_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili"><meta data-vue-meta="true" property="og:image" content="http://i2.hdslb.com/bfs/archive/8692211e9a756bab2ec31086679ae7664ff1c82b.jpg"><meta data-vue-meta="true" property="og:url" content="https://www.bilibili.com/video/av29306544/"><meta data-vue-meta="true" property="og:width" content="846"><meta data-vue-meta="true" property="og:height" content="566"> <link data-vue-meta="true" rel="canonical" href="https://www.bilibili.com/video/av29306544/"><script type="text/javascript">!function(){for(var o=window.navigator.userAgent,i=["Android","iPhone","SymbianOS","Windows Phone","iPod"],n=!0,e=0,r=i.length;e<r;e++)if(0<o.indexOf(i[e])){n=!1;break}if(!n){var w=window.location.origin.replace("www","m")+"/video/"+window.location.href.match(/av([0-9]+)/g)[0]+".html"+window.location.search;window.location.href=w}}(),window.spmReportData={},window.reportConfig={sample:1,scrollTracker:!0,msgObjects:"spmReportData",errorTracker:!0},window.biliPerformance=function(o){window.performance&&window.performance.timing&&(window.performance.timing[o]=(new Date).getTime())}</script><style>.ie-fix{background:#fff;position:fixed;left:0;top:0;right:0;bottom:0;widt ...

# %%
initial_state_text = match1(html_content,r'__INITIAL_STATE__=(.*?);\(function\(\)')  
initial_state_text
# Out:
# '{"aid":"29306544","p":"184","videoData":{"aid":29306544,"videos":345,"tid":39,"tname":"演讲• 公开课","copyright":2,"pic":"http:\\u002F\\u002Fi2.hdslb.com\\u002Fbfs\\u002Farchive\\u002F8692211e9a756bab2ec31086679ae7664ff1c82b.jpg","title":"【尚学堂】Java300集2019版--高淇","pubdate":1534212746,"ctime":1534212745,"desc":"关注订阅号「码匠笔记」回复「源码」获取 源码+课件","state":0,"attribute":16384,"duration":244381,"rights":{"bp":0,"elec":0,"download":1,"movie":0,"pay":0,"hd5":0,"no_reprint":0,"autoplay":1,"ugc_pay":0,"is_cooperation":0,"ugc_pay_preview":0},"owner":{"mid":7674303,"name":"哇哈是鸡肉味","face":"http:\\u002F\\u002Fi0.hdslb.com\\u002Fbfs\\u002Fface\\u002F475635f3cb0e541ef27439b101d747015ed17b6d.jpg"},"stat":{"aid":29306544,"view":"--","danmaku":"--","reply":1396,"favorite":"--","coin":"--","share":"--","now_rank":0,"his_rank":0,"like":"--","dislike":0},"dynamic":"","cid":94024988,"dimension":{"width":1624,"height":1080,"rotate":0},"no_cache":false,"pages":[{"cid":94024988,"page":1,"from":"vupload","part":"阅读视频前必看","duration":75,"vid":"","weblink":"","dimension":{"width":1624,"height":1080,"rotate":0}},{"cid":90549875,"page":2,"from":"vupload","part":"001_如何学习JAVA300集","duration":1091,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90550300,"page":3,"from":"vupload","part":"002_计算机发展史和未来方向","duration":1439,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90550827,"page":4,"from":"vupload","part":"003_多种编程语言介绍","duration":827,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551056,"page":5,"from":"vupload","part":"004_JAVA的发展历史和未来","duration":465,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551140,"page":6,"from":"vupload","part":"005_JAVA的核心优势和生态体系","duration":204,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551182,"page":7,"from":"vupload","part":"006_JAVA三大版本含义_JAVAME和安卓开发的关系","duration":314,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551249,"page":8,"from":"vupload","part":"007_JAVA的特性和优势","duration":309,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551325,"page":9,"from":"vupload","part":"008_JAVA应用程序的运行机制","duration":206,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551363,"page":10,"from":"vupload","part":"009_JDK和JRE和JVM的作用和区别","duration":196,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551416,"page":11,"from":"vupload","part":"010_JDK下载和安装_JDK目录介绍","duration":379,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551535,"page":12,"from":"vupload","part":"011_JDK环境变量PATH设置_classpath问题","duration":432,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551616,"page":13,"from":"vupload","part":"012_控制台测试JDK安装和配置成功","duration":150,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551653,"page":14,"from":"vupload","part":"013_写出第一个JAVA程序","duration":886,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551797,"page":15,"from":"vupload","part":"014_第一个JAVA程序错误总结","duration":392,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551888,"page":16,"from":"vupload","part":"015_第一个JAVA程序详细解析","duration":289,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551949,"page":17,"from":"vupload","part":"016_最常用DOS命令","duration":188,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90551995,"page":18,"from":"vupload","part":"017_常用开发工具介绍","duration":251,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90552059,"page":19,"from":"vupload","part":"018_eclipse开发环境使用原因","duration":146,"vid":"","weblink":"","dimension":{"width":1920,"height":1080,"rotate":0}},{"cid":90552082,"page":20," ...

# %%
initial_state = json.loads(initial_state_text)
initial_state
# Out:
# {'aid': '29306544',
#  'cidMap': {},
#  'comment': {'count': 1396,
#   'list': ['一起打卡学习~\n\n00，《Java 编程学习第一季》：av47103781\n00，《Java 企业开发第一季 - Spring 实战》：av47176832\n00，《Java 企业开发第二季 - MyBatis 实战》：av47228830\n00，《Java 企业开发第三季 - Spring MVC 实战》：av47218566\n00，《Java 企业开发第四季 - Spring Boot 实战》：av47230137\n00，《Java 企业开发第五季 - Spring Cloud 实战》：\n00，《Java 企业开发第六季 - Dubbo 实战》：av47009143\n00，《Java 企业开发第七季 - 电商项目实战》：av48308453\n\n00，《数据库第一季 - MySQL 实战》：av47702905\n00，《数据库第二季 - Redis 实战》：av47423174\n00，《数据库第三季 - MongoDB 实战》：av47425352\n00，《数据库第四季 - Elasticsearch 实战》：av48279989\n00，《数据库第五季 - Oracle 实战》：av48502473\n\n00，《前端开发第一季 - HTML + CSS 实战》：av49126649\n00，《前端开发第二季 - Javascript 实战》：av48927313\n00，《前端开发第三季 - React 实战》：av48033695\n00，《前端开发第四季 - Vue 实战》：av50886891\n00，《前端开发第五季 - React 项目实战》：av48495066\n00，《前端开发第六季 - Vue 项目实战》：av48333477\n\n00，《大数据开发第一季 - Hadoop》：av48621769\n00，《大数据开发第二季 - HBase》：av48581792\n00，《大数据开发第三季 - Hive》：av48609427\n00，《大数据开发第四季 - Flink》：av50996367\n00，《大数据开发第五季 - Spark》：av48668079\n\n00，《架构之路第一季 - RabbitMQ》：av48444262\n00，《架构之路第二季 - Kafka》：av47773990\n00，《架构之路第三季 - Zookeeper》：av47773419',
#    '飞机爆炸效果图链接：http://www.sxt.cn/Java_jQuery_in_action/thirteen-explosioneffect.html',
#    '第一天学习java！加油！争取看到60集。大一还没上课发现同学一个个都会很多编程知识，瑟瑟发抖，国庆疯狂补课。']},
#  'error': {},
#  'insertScripts': ['//s1.hdslb.com/bfs/static/jinkela/video/stardust-video.6d881c6b7684b56dbe818cc4209d6ec79d914194.js'],
#  'isClient': False,
#  'p': '184',
#  'player': '',
#  'playurl': {},
#  'related': [{'aid': 30023103,
#    'cid': 52309636,
#    'duration': 289780,
#    'owner': {'mid': 307235857, 'name': '一剑霜寒拾肆州'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/3116764138eac39e6106791a55f44ab39231d56c.jpg',
#    'stat': {'danmaku': 15175, 'view': 329975},
#    'title': '高淇老师应各位网友要求又更新了JAVA300集'},
#   {'aid': 34734817,
#    'cid': 60841758,
#    'duration': 95378,
#    'owner': {'mid': 14775858, 'name': 'Layne丶丶丶'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/2ec421169af09409dc5e1329c892b4b67adb959c.png',
#    'stat': {'danmaku': 28, 'view': 5175},
#    'title': '2018年尚学堂_高淇_Java300集（三）'},
#   {'aid': 24740240,
#    'cid': 41613061,
#    'duration': 1201,
#    'owner': {'mid': 194205757, 'name': '流年web前端'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/7dd2ed7a157c0e23da1ef36b46f067ba824f335e.jpg',
#    'stat': {'danmaku': 300, 'view': 188004},
#    'title': '程序员直播写代码，数十万网友捧场，看看这段代码有多牛掰'},
#   {'aid': 43896218,
#    'cid': 76905139,
#    'duration': 289790,
#    'owner': {'mid': 167879115, 'name': 'jaydenRobert'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/26a8e375c2a9588e3cbdc2d4889c476a9bdb9ebf.jpg',
#    'stat': {'danmaku': 602, 'view': 36780},
#    'title': '01_尚学堂_高淇_JAVA300集最新视频教程'},
#   {'aid': 14384439,
#    'cid': 23471202,
#    'duration': 7657,
#    'owner': {'mid': 15495878, 'name': '小兵张健'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/a6cfa8a3081fcf45df5f485563b738bd8b53a25e.jpg',
#    'stat': {'danmaku': 1, 'view': 2174},
#    'title': '尚学堂高淇springMVC'},
#   {'aid': 26670133,
#    'cid': 45877333,
#    'duration': 52,
#    'owner': {'mid': 44104284, 'name': '我真的是你的小姐姐'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/9fe8ac87bc7ff0790a0a2b4940b25bbbde0d89bc.jpg',
#    'stat': {'danmaku': 78, 'view': 54572},
#    'title': '程序员写200行表白代码，成就521对情侣，火遍抖音'},
#   {'aid': 34130960,
#    'cid': 59741880,
#    'duration': 64270,
#    'owner': {'mid': 291911401, 'name': '_Huxy'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/3914a7d779c2ce347a7a70a0b487b8dae3d99fbc.jpg',
#    'stat': {'danmaku': 56, 'view': 12928},
#    'title': '最新2018年尚学堂高淇python大型视频教程400集附素材+课上代码python基础教学视频python教学视频'},
#   {'aid': 39125808,
#    'cid': 71631646,
#    'duration': 234856,
#    'owner': {'mid': 358048574, 'name': '96312687051_bili'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/faa5466535a10c6fbd6c278837cf500cf00ccad8.jpg',
#    'stat': {'danmaku': 6, 'view': 1133},
#    'title': '2018尚学堂高淇_Java300集'},
#   {'aid': 34605506,
#    'cid': 60624074,
#    'duration': 73494,
#    'owner': {'mid': 14775858, 'name': 'Layne丶丶丶'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/2ec421169af09409dc5e1329c892b4b67adb959c.png',
#    'stat': {'danmaku': 86, 'view': 9002},
#    'title': '2018年尚学堂_高淇_Java300集（二）'},
#   {'aid': 34744910,
#    'cid': 60853751,
#    'duration': 57176,
#    'owner': {'mid': 14775858, 'name': 'Layne丶丶丶'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/2ec421169af09409dc5e1329c892b4b67adb959c.png',
#    'stat': {'danmaku': 3, 'view': 1623},
#    'title': '2018年尚学堂_高淇_Java300集（四）'},
#   {'aid': 14184325,
#    'cid': 23153678,
#    'duration': 197388,
#    'owner': {'mid': 37974444, 'name': '黑马程序员'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/3992190257601fceb4725f3df91cc94b8a8e37cd.jpg',
#    'stat': {'danmaku': 50609, 'view': 2085622},
#    'title': 'Python教程_600集Python从入门到精通教程（懂中文就能学会）'},
#   {'aid': 31697253,
#    'cid': 55429888,
#    'duration': 7675,
#    'owner': {'mid': 131494610, 'name': '轻松学Python'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/7f7074741146e8882a37abec2bb491f33c1f19c9.jpg',
#    'stat': {'danmaku': 1986, 'view': 289582},
#    'title': '自从学会了Python，我从来不为看什么电影发愁，好看的，付费的，百度不到资源的全部一网打井！'},
#   {'aid': 38374554,
#    'cid': 67439490,
#    'duration': 288820,
#    'owner': {'mid': 6530558, 'name': 'yue204'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/6ffd679573b55d4633fc0066321cc2ccff808f9b.jpg',
#    'stat': {'danmaku': 48, 'view': 6862},
#    'title': '尚学堂2018java300集'},
#   {'aid': 24176315,
#    'cid': 40522543,
#    'duration': 43135,
#    'owner': {'mid': 22046211, 'name': '初心不忘誓言封存'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/bdf023350d78ef7f14a4bfe091aaf69b314f63c0.jpg',
#    'stat': {'danmaku': 1197, 'view': 61051},
#    'title': '23个设计模式'},
#   {'aid': 26394341,
#    'cid': 45352253,
#    'duration': 16602,
#    'owner': {'mid': 3620335, 'name': 'Yukki☆Asuna'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/517bb5a24cff6b29b1933a84f3bb2ba861002a44.jpg',
#    'stat': {'danmaku': 104, 'view': 15763},
#    'title': '尚学堂_第8章_数组（快速排序，冒泡排序，选择排序，二分法查找）'},
#   {'aid': 11938917,
#    'cid': 19707354,
#    'duration': 41598,
#    'owner': {'mid': 13683210, 'name': 'APP良心猫'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/4a82b560afb613ba527af055766bbb9ca4c4bb9b.png',
#    'stat': {'danmaku': 4266, 'view': 232923},
#    'title': '【微信小程序】从入门到入土课程'},
#   {'aid': 27925923,
#    'cid': 48225242,
#    'duration': 63990,
#    'owner': {'mid': 294588990, 'name': '爱分享的小宅'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/f77ba9b7fa5c942f73c5e8f7a54ca2cccf93da00.jpg',
#    'stat': {'danmaku': 108, 'view': 17681},
#    'title': '2018年尚学堂高淇python400集教程'},
#   {'aid': 10428929,
#    'cid': 17222382,
#    'duration': 4151,
#    'owner': {'mid': 99940470, 'name': '我就是老肖'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/fbf3dedc6f57bec794f3b800b03949e5d1b8d65d.jpg',
#    'stat': {'danmaku': 285, 'view': 19044},
#    'title': '某个被问懵逼的培训生。'},
#   {'aid': 22589746,
#    'cid': 37464013,
#    'duration': 1800,
#    'owner': {'mid': 153075316, 'name': 'java皮囊'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/2c36931d658a7cbe8a90d98f725af73befc8df7d.jpg',
#    'stat': {'danmaku': 109, 'view': 198055},
#    'title': '年薪80万的骨灰级程序员直播敲代码，看看菜鸟与大咖的区别'},
#   {'aid': 38379214,
#    'cid': 67540408,
#    'duration': 55718,
#    'owner': {'mid': 37974444, 'name': '黑马程序员'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/eda76607b36a3b27ada472d2215aece88d3c83c7.jpg',
#    'stat': {'danmaku': 214, 'view': 39045},
#    'title': 'Java进阶教程2018年spring框架深入浅出'},
#   {'aid': 24181212,
#    'cid': 40531242,
#    'duration': 57654,
#    'owner': {'mid': 330076415, 'name': '爱马士粉丝团长'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/a86f894c759c7034dcb9b5f6d14f9714d0a44f5c.jpg',
#    'stat': {'danmaku': 46, 'view': 25688},
#    'title': '【马士兵老师】带你入门学习大数据、架构，年薪50万（底薪+股票）都不是梦，可以加关注。'},
#   {'aid': 26931969,
#    'cid': 46379074,
#    'duration': 44,
#    'owner': {'mid': 44104284, 'name': '我真的是你的小姐姐'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/cd5e4049c2f0b8ec4c92432f005b10d74b76ee99.jpg',
#    'stat': {'danmaku': 422, 'view': 504490},
#    'title': '程序员面试因年龄大遭嫌弃，200行代码写下这个特效后，收到5份offer'},
#   {'aid': 24042956,
#    'cid': 40262277,
#    'duration': 10763,
#    'owner': {'mid': 87567894, 'name': 'Anarkh-Lee'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/1213a55abbed1ccbd70b6d17df46464b60702a54.png',
#    'stat': {'danmaku': 91, 'view': 31090},
#    'title': 'Eclipse视频教程'},
#   {'aid': 34020433,
#    'cid': 59581705,
#    'duration': 108222,
#    'owner': {'mid': 177209506, 'name': '秋的影子'},
#    'pic': 'http://i1.hdslb.com/bfs/vc/i181017ws974dnw9kbdz72fab8fz115g_0022.jpg',
#    'stat': {'danmaku': 201, 'view': 36805},
#    'title': '清华-微机原理与接口技术'},
#   {'aid': 19940317,
#    'cid': 32524337,
#    'duration': 6693,
#    'owner': {'mid': 37422870, 'name': 'HACK学习'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/716e0f721b2a252a21a800a26ab5477f4edf89d2.jpg',
#    'stat': {'danmaku': 263, 'view': 87804},
#    'title': '【2018黑客编程入门】Python黑客编程基础入门'},
#   {'aid': 27140815,
#    'cid': 46767115,
#    'duration': 57234,
#    'owner': {'mid': 281662575, 'name': 'vecjt'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/76e98b3cfde3aa76649173ab818e78aaffc0e0d4.jpg',
#    'stat': {'danmaku': 1102, 'view': 162277},
#    'title': 'Python400集（第一季）'},
#   {'aid': 29949119,
#    'cid': 52159119,
#    'duration': 110717,
#    'owner': {'mid': 16936914, 'name': '我真的不是Iolicon啊'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/5ec88cbacc88c9af37331a83da3b8dc65afa56d9.jpg',
#    'stat': {'danmaku': 946, 'view': 82723},
#    'title': '计算机组成原理（唐朔飞）'},
#   {'aid': 23360560,
#    'cid': 38929137,
#    'duration': 64480,
#    'owner': {'mid': 37623364, 'name': 'LowerAI'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/0347d6ebd84435150434e4c49767a4f217faa8a5.png',
#    'stat': {'danmaku': 3097, 'view': 133500},
#    'title': '黑马程序员-linux从入门到精通'},
#   {'aid': 26001719,
#    'cid': 44550870,
#    'duration': 39,
#    'owner': {'mid': 44104284, 'name': '我真的是你的小姐姐'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/46d41fd516b643d09a5d4a394b70056c2009be1c.jpg',
#    'stat': {'danmaku': 134, 'view': 242541},
#    'title': '月薪3.8万的程序员到底有多强？1分钟带你领略前端的强大'},
#   {'aid': 29224472,
#    'cid': 50740882,
#    'duration': 2701,
#    'owner': {'mid': 350900895, 'name': '伊卡洛斯的复活'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/f0bd599a4ba403c797fb119d7bc4814edb984ef6.jpg',
#    'stat': {'danmaku': 35, 'view': 50858},
#    'title': '想入编程坑，过来人告诉你：培训机构到底值不值得去？'},
#   {'aid': 38631386,
#    'cid': 67907165,
#    'duration': 27339,
#    'owner': {'mid': 386968039, 'name': 'lionelkk'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/c3710044b5e2a070e627ac5fb4e2192c69513f16.jpg',
#    'stat': {'danmaku': 0, 'view': 961},
#    'title': '高琪JAVA300集'},
#   {'aid': 16757462,
#    'cid': 27380538,
#    'duration': 28704,
#    'owner': {'mid': 240874216, 'name': '梦里花落听春雨'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/91cb81039fbe5504f55c517c4af552c78eede889.jpg',
#    'stat': {'danmaku': 60, 'view': 6131},
#    'title': '尚学堂_高淇Servlet'},
#   {'aid': 40066037,
#    'cid': 70361643,
#    'duration': 289790,
#    'owner': {'mid': 6969417, 'name': '艾恩雪代'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/7f7122bceb4f131ef7efe2542c02156110f1b796.jpg',
#    'stat': {'danmaku': 5, 'view': 902},
#    'title': '尚学堂JAVA300集'},
#   {'aid': 33988391,
#    'cid': 59524070,
#    'duration': 86158,
#    'owner': {'mid': 9325802, 'name': 'Vast_universe'},
#    'pic': 'http://i1.hdslb.com/bfs/archive/3dfb8c5a65d4975ea9a32bcc787611ab3a83063b.jpg',
#    'stat': {'danmaku': 1, 'view': 983},
#    'title': '【尚学堂】Java300集最新版-高淇'},
#   {'aid': 19130135,
#    'cid': 31203300,
#    'duration': 1114,
#    'owner': {'mid': 153075316, 'name': 'java皮囊'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/c0d4ab8ff123cded0e59c37acc7b23ecf40743d5.jpg',
#    'stat': {'danmaku': 755, 'view': 245657},
#    'title': '月薪30万的程序员到底有多强'},
#   {'aid': 26350676,
#    'cid': 45259003,
#    'duration': 29548,
#    'owner': {'mid': 3620335, 'name': 'Yukki☆Asuna'},
#    'pic': 'http://i2.hdslb.com/bfs/archive/844b2db9f4edf234b1297a1c8ee123c558b29756.jpg',
#    'stat': {'danmaku': 132, 'view': 10034},
#    'title': '尚学堂_第6章_面向对象（继承，封装，多态，接口，内部类等）'},
#   {'aid': 20436259,
#    'cid': 33406281,
#    'duration': 38352,
#    'owner': {'mid': 37974444, 'name': '黑马程序员'},
#    'pic': 'http://i0.hdslb.com/bfs/archive/4ccba790691745714f43a96b5ff7fdd3b4f1a67b.jpg',
#    'stat': {'danmaku': 1076, 'view': 86290},
#    'title': '5天软件测试从入门到精通'}],
#  'staffData': [],
#  'tags': [{'attribute': 0,
#    'content': '',
#    'count': {'atten': 1269, 'use': 14172, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 10,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 11072,
#    'tag_name': 'JAVA',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 6001, 'use': 26789, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 0,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 8,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 14932,
#    'tag_name': '程序员',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 103247, 'use': 223664, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 5,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 31864,
#    'tag_name': '公开课',
#    'timeOut': None,
#    'type': 2},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 55074, 'use': 358822, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 0,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 4,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 4149,
#    'tag_name': '教育',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 29410, 'use': 146244, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 0,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 4,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 8859,
#    'tag_name': '考试',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 277700, 'use': 838669, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 4,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 13160,
#    'tag_name': '学习',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 42174, 'use': 278183, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 4,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 28310,
#    'tag_name': '视频教程',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 31144, 'use': 183602, 'view': 0},
#    'cover': '',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 3,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 154551,
#    'tag_name': '课程',
#    'timeOut': None,
#    'type': 3},
#   {'attribute': 0,
#    'content': '编程是使用指令操控计算机的过程。操控计算机的指令统称编程语言，并分3大派：机械语言，汇编语言及高级语言。机器语言为低级的2进制码，仅在该机器语言的机器体系上适用，汇器是机械语言的基本翻译，但可读性/兼容性还是很差。高级语言是所有非汇编/机器语言的集合，一般可读性/兼容性更高。高级语言分多类，如：面向过程(Procedure Oriented)，面向对象(Object Oriented),多多重编程范式(Multi-paradigm),函数式(functional)，静态/动态(static/dynamic)等等。机器语言，汇编语言&amp;大部分高级语言都是图灵等价和图灵完备的，也是说机器语言，汇编语言&amp;大部分高级语言都可以模拟单带图灵机，并单带图灵机可以模拟说机器语言，汇编语言大部分高级语言。非图灵完备的计算机语言为DSL(领域特定语言),只适用特定的场合，如latex，yacc及lex。',
#    'count': {'atten': 89920, 'use': 79535, 'view': 0},
#    'cover': 'http://i0.hdslb.com/bfs/tag/4abd492394b43d415d79dce5055670e72737b088.jpg',
#    'ctime': 1436866637,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 3,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 28784,
#    'tag_name': '编程',
#    'timeOut': None,
#    'type': 2},
#   {'attribute': 0,
#    'content': '',
#    'count': {'atten': 21657, 'use': 77452, 'view': 0},
#    'cover': '',
#    'ctime': 1443672619,
#    'hated': 0,
#    'hates': 1,
#    'head_cover': '',
#    'is_atten': 0,
#    'liked': 0,
#    'likes': 3,
#    'short_content': '',
#    'showDetail': False,
#    'showReport': False,
#    'state': 0,
#    'tag_id': 1377639,
#    'tag_name': '线上课堂',
#    'timeOut': None,
#    'type': 0}],
#  'upData': {'DisplayRank': '0',
#   'Official': {'desc': '', 'role': 0, 'title': ''},
#   'approve': False,
#   'archiveCount': 1,
#   'article': 0,
#   'attention': 11,
#   'attentions': [],
#   'birthday': '',
#   'description': '',
#   'face': 'http://i0.hdslb.com/bfs/face/475635f3cb0e541ef27439b101d747015ed17b6d.jpg',
#   'fans': 14894,
#   'friend': 11,
#   'level_info': {'current_exp': 0,
#    'current_level': 5,
#    'current_min': 0,
#    'next_exp': 0},
#   'mid': '7674303',
#   'name': '哇哈是鸡肉味',
#   'nameplate': {'condition': '',
#    'image': '',
#    'image_small': '',
#    'level': '',
#    'name': '',
#    'nid': 0},
#   'official_verify': {'desc': '', 'type': -1},
#   'pendant': {'expire': 0, 'image': '', 'name': '', 'pid': 0},
#   'place': '',
#   'rank': '10000',
#   'regtime': 0,
#   'sex': '保密',
#   'sign': '',
#   'spacesta': 0,
#   'vip': {'accessStatus': 0,
#    'dueRemark': '',
#    'theme_type': 0,
#    'vipStatus': 0,
#    'vipStatusWarn': '',
#    'vipType': 0}},
#  'user': {},
#  'videoData': {'aid': 29306544,
#   'attribute': 16384,
#   'cid': 94024988,
#   'copyright': 2,
#   'ctime': 1534212745,
#   'desc': '关注订阅号「码匠笔记」回复「源码」获取 源码+课件',
#   'dimension': {'height': 1080, 'rotate': 0, 'width': 1624},
#   'duration': 244381,
#   'dynamic': '',
#   'embedPlayer': 'EmbedPlayer("player", "//s1.hdslb.com/bfs/static/player/main/flash/play.swf", "cid=90571660&aid=29306544&pre_ad=")',
#   'no_cache': False,
#   'owner': {'face': 'http://i0.hdslb.com/bfs/face/475635f3cb0e541ef27439b101d747015ed17b6d.jpg',
#    'mid': 7674303,
#    'name': '哇哈是鸡肉味'},
#   'pages': [{'cid': 94024988,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1624},
#     'duration': 75,
#     'from': 'vupload',
#     'page': 1,
#     'part': '阅读视频前必看',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90549875,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1091,
#     'from': 'vupload',
#     'page': 2,
#     'part': '001_如何学习JAVA300集',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90550300,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1439,
#     'from': 'vupload',
#     'page': 3,
#     'part': '002_计算机发展史和未来方向',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90550827,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 827,
#     'from': 'vupload',
#     'page': 4,
#     'part': '003_多种编程语言介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551056,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 465,
#     'from': 'vupload',
#     'page': 5,
#     'part': '004_JAVA的发展历史和未来',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551140,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 204,
#     'from': 'vupload',
#     'page': 6,
#     'part': '005_JAVA的核心优势和生态体系',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551182,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 314,
#     'from': 'vupload',
#     'page': 7,
#     'part': '006_JAVA三大版本含义_JAVAME和安卓开发的关系',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551249,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 309,
#     'from': 'vupload',
#     'page': 8,
#     'part': '007_JAVA的特性和优势',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551325,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 206,
#     'from': 'vupload',
#     'page': 9,
#     'part': '008_JAVA应用程序的运行机制',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551363,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 196,
#     'from': 'vupload',
#     'page': 10,
#     'part': '009_JDK和JRE和JVM的作用和区别',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551416,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 379,
#     'from': 'vupload',
#     'page': 11,
#     'part': '010_JDK下载和安装_JDK目录介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551535,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 432,
#     'from': 'vupload',
#     'page': 12,
#     'part': '011_JDK环境变量PATH设置_classpath问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551616,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 150,
#     'from': 'vupload',
#     'page': 13,
#     'part': '012_控制台测试JDK安装和配置成功',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551653,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 886,
#     'from': 'vupload',
#     'page': 14,
#     'part': '013_写出第一个JAVA程序',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551797,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 392,
#     'from': 'vupload',
#     'page': 15,
#     'part': '014_第一个JAVA程序错误总结',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551888,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 289,
#     'from': 'vupload',
#     'page': 16,
#     'part': '015_第一个JAVA程序详细解析',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551949,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 188,
#     'from': 'vupload',
#     'page': 17,
#     'part': '016_最常用DOS命令',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90551995,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 251,
#     'from': 'vupload',
#     'page': 18,
#     'part': '017_常用开发工具介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552059,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 146,
#     'from': 'vupload',
#     'page': 19,
#     'part': '018_eclipse开发环境使用原因',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552082,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 193,
#     'from': 'vupload',
#     'page': 20,
#     'part': '019_eclipse下载版本选择和使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552117,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 216,
#     'from': 'vupload',
#     'page': 21,
#     'part': '020_eclipse下建立JAVA项目_项目的结构',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552154,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 273,
#     'from': 'vupload',
#     'page': 22,
#     'part': '021_eclipse开发和运行JAVA程序',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552205,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1859,
#     'from': 'vupload',
#     'page': 23,
#     'part': '022_37分钟零基础开发桌球小游戏项目~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552386,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 428,
#     'from': 'vupload',
#     'page': 24,
#     'part': '023_注释(单行注释、多行注释、文档注释)',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552439,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 475,
#     'from': 'vupload',
#     'page': 25,
#     'part': '024_标识符规则_驼峰规则',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552507,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 122,
#     'from': 'vupload',
#     'page': 26,
#     'part': '025_JAVA的关键字保留字',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552548,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 519,
#     'from': 'vupload',
#     'page': 27,
#     'part': '026_变量的本质_声明格式和初始化问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552614,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 467,
#     'from': 'vupload',
#     'page': 28,
#     'part': '027_变量分类(局部变量、成员变量、静态变量)',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552683,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 292,
#     'from': 'vupload',
#     'page': 29,
#     'part': '028_常量和final',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552738,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 159,
#     'from': 'vupload',
#     'page': 30,
#     'part': '029_基本数据类型介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552768,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 756,
#     'from': 'vupload',
#     'page': 31,
#     'part': '030_整型变量和整型常量',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552834,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 721,
#     'from': 'vupload',
#     'page': 32,
#     'part': '031_浮点型变量和BigDecimal的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552933,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 449,
#     'from': 'vupload',
#     'page': 33,
#     'part': '032_字符型类型_转义字符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90552975,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 261,
#     'from': 'vupload',
#     'page': 34,
#     'part': '033_布尔型_if语句使用要点',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553002,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 73,
#     'from': 'vupload',
#     'page': 35,
#     'part': '034_运算符介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553026,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 602,
#     'from': 'vupload',
#     'page': 36,
#     'part': '035_算术运算符(二元、自增和自减)',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553094,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 222,
#     'from': 'vupload',
#     'page': 37,
#     'part': '036_赋值和赋值扩展运算符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553122,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 294,
#     'from': 'vupload',
#     'page': 38,
#     'part': '037_关系运算符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553169,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 617,
#     'from': 'vupload',
#     'page': 39,
#     'part': '038_逻辑运算符_短路运算详解',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553233,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 449,
#     'from': 'vupload',
#     'page': 40,
#     'part': '039_位运算符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553309,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 345,
#     'from': 'vupload',
#     'page': 41,
#     'part': '040_字符串连接符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553356,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 328,
#     'from': 'vupload',
#     'page': 42,
#     'part': '041_条件运算符目',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553410,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 279,
#     'from': 'vupload',
#     'page': 43,
#     'part': '042_运算符优先级_逻辑与或优先问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553461,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 410,
#     'from': 'vupload',
#     'page': 44,
#     'part': '043_自动类型转化~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553534,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 143,
#     'from': 'vupload',
#     'page': 45,
#     'part': '044_强制类型转换',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553564,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 234,
#     'from': 'vupload',
#     'page': 46,
#     'part': '045_基本类型常见错误_溢出_L问题~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553621,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 420,
#     'from': 'vupload',
#     'page': 47,
#     'part': '046_使用Scanner获得键盘输入~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553684,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 270,
#     'from': 'vupload',
#     'page': 48,
#     'part': '047_控制语句介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553742,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 593,
#     'from': 'vupload',
#     'page': 49,
#     'part': '048_控制语句_if单选择结构~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553846,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 302,
#     'from': 'vupload',
#     'page': 50,
#     'part': '049_ifelse双选择结构~1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553911,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 234,
#     'from': 'vupload',
#     'page': 51,
#     'part': '050_ifelseifelse多选择结构',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90553961,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 599,
#     'from': 'vupload',
#     'page': 52,
#     'part': '051_switch语句的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554108,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 531,
#     'from': 'vupload',
#     'page': 53,
#     'part': '052_while循环详解',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554199,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 584,
#     'from': 'vupload',
#     'page': 54,
#     'part': '053_for循环详解_dowhile简介',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554315,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1233,
#     'from': 'vupload',
#     'page': 55,
#     'part': '054_嵌套循环_循环相关练习',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554537,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 489,
#     'from': 'vupload',
#     'page': 56,
#     'part': '055_break和continue语句',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554657,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 356,
#     'from': 'vupload',
#     'page': 57,
#     'part': '056_带标签的break和continue',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554722,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 987,
#     'from': 'vupload',
#     'page': 58,
#     'part': '057_方法的定义_形参_实参_返回值_语句块',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554897,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 472,
#     'from': 'vupload',
#     'page': 59,
#     'part': '058_方法的重载overload',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90554981,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 920,
#     'from': 'vupload',
#     'page': 60,
#     'part': '059_递归算法详解_递归和迭代效率测试',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555215,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 682,
#     'from': 'vupload',
#     'page': 61,
#     'part': '060_面向过程和面向对象区别',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555339,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 755,
#     'from': 'vupload',
#     'page': 62,
#     'part': '061_对象是什么_对象和数据管理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555490,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 712,
#     'from': 'vupload',
#     'page': 63,
#     'part': '062_对象和类的关系_属性_成员变量_方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555601,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 550,
#     'from': 'vupload',
#     'page': 64,
#     'part': '063_一个典型类的写法和调用_类的UML图入门',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555680,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1602,
#     'from': 'vupload',
#     'page': 65,
#     'part': '064_内存分析详解_栈_堆_方法区_栈帧_程序执行的内存变化过程',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90555925,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 699,
#     'from': 'vupload',
#     'page': 66,
#     'part': '065_构造方法详解_构造方法重载',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556042,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 367,
#     'from': 'vupload',
#     'page': 67,
#     'part': '066_垃圾回收机制介绍_垃圾回收算法(引用计数和引用可达)',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556102,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 542,
#     'from': 'vupload',
#     'page': 68,
#     'part': '067_通用分代垃圾回收详解',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556252,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 417,
#     'from': 'vupload',
#     'page': 69,
#     'part': '068_this的本质_对象创建过程的4步',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556298,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 562,
#     'from': 'vupload',
#     'page': 70,
#     'part': '069_static关键字_内存分析静态变量和静态方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556357,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 259,
#     'from': 'vupload',
#     'page': 71,
#     'part': '070_静态初始化块_继承树的追溯',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556397,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 575,
#     'from': 'vupload',
#     'page': 72,
#     'part': '071_JAVA的参数传值机制_值传递',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556465,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 584,
#     'from': 'vupload',
#     'page': 73,
#     'part': '072_java包机制_package的使用_JDK提供的常见包的作用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556527,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 592,
#     'from': 'vupload',
#     'page': 74,
#     'part': '073_import详解_静态导入详解',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556579,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 937,
#     'from': 'vupload',
#     'page': 75,
#     'part': '074_继承_instanceOf的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556682,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 496,
#     'from': 'vupload',
#     'page': 76,
#     'part': '075_方法的重写override_返回值类型问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556727,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 550,
#     'from': 'vupload',
#     'page': 77,
#     'part': '076_Object类的用法_重写toString方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556805,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 684,
#     'from': 'vupload',
#     'page': 78,
#     'part': '077_equals方法的重写_阅读Object和String的源码',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556885,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 560,
#     'from': 'vupload',
#     'page': 79,
#     'part': '078_super父类对象引用_继承树追溯问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90556957,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 933,
#     'from': 'vupload',
#     'page': 80,
#     'part': '079_封装的使用_访问控制符',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557075,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 742,
#     'from': 'vupload',
#     'page': 81,
#     'part': '080_封装的使用细节_javabean的规则',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557164,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 587,
#     'from': 'vupload',
#     'page': 82,
#     'part': '081_多态_多态的三个必要条件',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557263,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 300,
#     'from': 'vupload',
#     'page': 83,
#     'part': '082_对象的转型_向上自动转型_向下强制转型_ClassCastException处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557329,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 172,
#     'from': 'vupload',
#     'page': 84,
#     'part': '083_final修饰变量和方法和类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557370,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 970,
#     'from': 'vupload',
#     'page': 85,
#     'part': '084_数组的使用_内存状态_动态初始化和遍历_数组越界异常',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557497,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 247,
#     'from': 'vupload',
#     'page': 86,
#     'part': '085_数组的3种初始化方式_静态初始化_动态初始化_默认初始化',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557549,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 216,
#     'from': 'vupload',
#     'page': 87,
#     'part': '086_数组的遍历_foreach循环',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557647,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 706,
#     'from': 'vupload',
#     'page': 88,
#     'part': '087_游戏项目介绍_建立游戏主窗口',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557729,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 751,
#     'from': 'vupload',
#     'page': 89,
#     'part': '088_图形绘制_文本绘制_颜色改变_图像对象的加载',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557810,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 591,
#     'from': 'vupload',
#     'page': 90,
#     'part': '089_线程内部类实现动画',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557896,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 453,
#     'from': 'vupload',
#     'page': 91,
#     'part': '090_游戏物体根类的实现',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90557955,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 407,
#     'from': 'vupload',
#     'page': 92,
#     'part': '091_面向对象思想重构飞机类设计',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558003,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 286,
#     'from': 'vupload',
#     'page': 93,
#     'part': '092_键盘控制游戏物体原理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558047,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 617,
#     'from': 'vupload',
#     'page': 94,
#     'part': '093_面向对象重构飞机类的键盘控制代码',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558117,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 844,
#     'from': 'vupload',
#     'page': 95,
#     'part': '094_炮弹类设计_任意角度飞行',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558181,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 207,
#     'from': 'vupload',
#     'page': 96,
#     'part': '095_容器或数组产生多发炮弹',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558223,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 336,
#     'from': 'vupload',
#     'page': 97,
#     'part': '096_双缓冲解决闪烁问题_矩形检测原理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558269,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 385,
#     'from': 'vupload',
#     'page': 98,
#     'part': '097_炮弹和飞机的碰撞检测_飞机死掉',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558346,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 248,
#     'from': 'vupload',
#     'page': 99,
#     'part': '098_爆炸类_图片数组轮播处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558380,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 290,
#     'from': 'vupload',
#     'page': 100,
#     'part': '099_主窗口画出爆炸类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558411,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 514,
#     'from': 'vupload',
#     'page': 101,
#     'part': '100_飞机死亡和计时功能',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558511,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 275,
#     'from': 'vupload',
#     'page': 102,
#     'part': '101_总结和期望',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558810,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 555,
#     'from': 'vupload',
#     'page': 103,
#     'part': '102. 抽象类_抽象方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90558869,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1212,
#     'from': 'vupload',
#     'page': 104,
#     'part': '103. 接口详解_多继承_面向接口编程',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559005,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1239,
#     'from': 'vupload',
#     'page': 105,
#     'part': '104. 内部类_静态和非静态内部类_匿名内部类_方法内部类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559156,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 627,
#     'from': 'vupload',
#     'page': 106,
#     'part': '105. String类_常量池_字符串比较',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559234,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1048,
#     'from': 'vupload',
#     'page': 107,
#     'part': '106. String类常用方法_API阅读',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559412,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1570,
#     'from': 'vupload',
#     'page': 108,
#     'part': '107. 数组的拷贝_插入和删除元素本质_数组扩容操作',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559550,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 435,
#     'from': 'vupload',
#     'page': 109,
#     'part': '108. Arrays工具类的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559623,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 592,
#     'from': 'vupload',
#     'page': 110,
#     'part': '109. 多维数组_内存分析',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559668,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 401,
#     'from': 'vupload',
#     'page': 111,
#     'part': '110. 多维数组存储表格数据',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559705,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 956,
#     'from': 'vupload',
#     'page': 112,
#     'part': '111. 冒泡排序_优化排序',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90559819,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 589,
#     'from': 'vupload',
#     'page': 113,
#     'part': '112. 二分法查找_折半检索',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90560935,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 901,
#     'from': 'vupload',
#     'page': 114,
#     'part': '113. 包装类_Integer_Number_JDK源码分析',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561040,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 756,
#     'from': 'vupload',
#     'page': 115,
#     'part': '114. 包装类_自动装箱和拆箱_缓存源码分析',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561152,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 682,
#     'from': 'vupload',
#     'page': 116,
#     'part': '115. String类源码分析_不可变和可变字符序列区别_字符串比较核心要点',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561232,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 971,
#     'from': 'vupload',
#     'page': 117,
#     'part': '116. StringBuilder和StringBuffer用法_不可变和可变字符序列使用陷阱',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561356,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 787,
#     'from': 'vupload',
#     'page': 118,
#     'part': '117. Date时间类_JDK源码分析',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561507,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 741,
#     'from': 'vupload',
#     'page': 119,
#     'part': '118. DateFormat和SimpleDateFormat的使用_时间和字符串互相转换',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561660,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1384,
#     'from': 'vupload',
#     'page': 120,
#     'part': '119. Calendar和GregorianCalendar的使用_日期计算',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90561923,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 858,
#     'from': 'vupload',
#     'page': 121,
#     'part': '120. 可视化日历程序_1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562078,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 651,
#     'from': 'vupload',
#     'page': 122,
#     'part': '121. 可视化日历程序_2_Math和Random类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562259,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 660,
#     'from': 'vupload',
#     'page': 123,
#     'part': '122. File类的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562408,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 535,
#     'from': 'vupload',
#     'page': 124,
#     'part': '123. File类_递归打印目录树结构',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562532,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 358,
#     'from': 'vupload',
#     'page': 125,
#     'part': '124. 枚举基本用法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562610,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 936,
#     'from': 'vupload',
#     'page': 126,
#     'part': '125. 异常机制_Exception_Error_Throwable',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562815,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 567,
#     'from': 'vupload',
#     'page': 127,
#     'part': '126. 常见异常分类_运行时异常的处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90562944,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 961,
#     'from': 'vupload',
#     'page': 128,
#     'part': '127. 异常处理1_捕获_try_catch_finally',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563146,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 328,
#     'from': 'vupload',
#     'page': 129,
#     'part': '128. 异常处理2_声明异常',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563221,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 349,
#     'from': 'vupload',
#     'page': 130,
#     'part': '129. 利用百度解决异常问题_程序员修炼手册',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563355,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 467,
#     'from': 'vupload',
#     'page': 131,
#     'part': '130. 手动抛出异常_自定义异常_总结',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563417,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 320,
#     'from': 'vupload',
#     'page': 132,
#     'part': '131. 容器架构介绍_数组优劣势',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563468,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 808,
#     'from': 'vupload',
#     'page': 133,
#     'part': '132. 泛型概念_自定义泛型',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563585,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 338,
#     'from': 'vupload',
#     'page': 134,
#     'part': '133. 容器泛型_底层源码解读',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563688,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 842,
#     'from': 'vupload',
#     'page': 135,
#     'part': '134. Collection接口_List接口_ArrayList常用方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563871,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 544,
#     'from': 'vupload',
#     'page': 136,
#     'part': '135. ArrayList_操作多个List_并集和交集',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90563947,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 821,
#     'from': 'vupload',
#     'page': 137,
#     'part': '136. ArrayList_索引和顺序相关方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90564046,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 848,
#     'from': 'vupload',
#     'page': 138,
#     'part': '137. ArrayList_底层JDK源码解读',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90564165,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 715,
#     'from': 'vupload',
#     'page': 139,
#     'part': '138. 手工实现ArrayList1_最简化方式_增加泛型',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90564261,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
# ...
#     'part': '269_【GOF23设计模式】_解释器模式_访问者模_数学表达式动态解析库式',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647578,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1061,
#     'from': 'vupload',
#     'page': 279,
#     'part': '270_【GOF23设计模式】_策略模式_CRM中报价策略_GUI编程中布局管理器底层架构',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647642,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 842,
#     'from': 'vupload',
#     'page': 280,
#     'part': '271_【GOF23设计模式】_模板方法模式_钩子函数_方法回调_好莱坞原则',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647687,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1439,
#     'from': 'vupload',
#     'page': 281,
#     'part': '272_【GOF23设计模式】_状态模式_UML状态图_酒店系统房间状态_线程对象状态切换',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647779,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1244,
#     'from': 'vupload',
#     'page': 282,
#     'part': '273_【GOF23设计模式】_观察者模式_广播机制_消息订阅_网络游戏对战原理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647856,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 695,
#     'from': 'vupload',
#     'page': 283,
#     'part': '274_【GOF23设计模式】_观察者模式_obserable类和observer接口_应用场景总结',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90647910,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1093,
#     'from': 'vupload',
#     'page': 284,
#     'part': '275_【GOF23设计模式】_备忘录模式_多点备忘_事务操作_回滚数据底层架构',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655743,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1028,
#     'from': 'vupload',
#     'page': 285,
#     'part': '276_正则表达式_介绍_标准字符集合_自定义字符集合_01',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655773,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 677,
#     'from': 'vupload',
#     'page': 286,
#     'part': '277_正则表达式_自定义字符集合特殊用法_量词_贪婪和非贪婪模式_02',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655800,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 627,
#     'from': 'vupload',
#     'page': 287,
#     'part': '278_正则表达式_字符边界_匹配模式(单行和多行模式)_03',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655827,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 522,
#     'from': 'vupload',
#     'page': 288,
#     'part': '279_正则表达式_分支结构_捕获组_非捕获组_反向引用_04',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655846,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 394,
#     'from': 'vupload',
#     'page': 289,
#     'part': '280_正则表达式_预搜索_零宽断言(4个语法结构)_05',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655855,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 550,
#     'from': 'vupload',
#     'page': 290,
#     'part': '281_正则表达式_电话号码_手机号码_邮箱_常用表达式_06',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655870,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 360,
#     'from': 'vupload',
#     'page': 291,
#     'part': '282_正则表达式_开发环境_文本编辑器中使用_07',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655891,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1097,
#     'from': 'vupload',
#     'page': 292,
#     'part': '283_正则表达式_JAVA编程中使用_查找_替换_分割_08',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655930,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1435,
#     'from': 'vupload',
#     'page': 293,
#     'part': '284_正则表达式_手写网络爬虫_基本原理_乱码处理_09',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90655992,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 863,
#     'from': 'vupload',
#     'page': 294,
#     'part': '285_JDBC_mysql安装和启动_安装问题的解决',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656030,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 553,
#     'from': 'vupload',
#     'page': 295,
#     'part': '286_JDBC_mysql_navicat客户端软件使用_建库_建表_主键自增_SQL执行',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656043,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 537,
#     'from': 'vupload',
#     'page': 296,
#     'part': '287_JDBC_mysql_环境变量配置_命令行模式操作',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656069,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1041,
#     'from': 'vupload',
#     'page': 297,
#     'part': '288_JDBC_设计架构_驱动类加载_建立Connection_效率测试',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656117,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 653,
#     'from': 'vupload',
#     'page': 298,
#     'part': '289_JDBC_statement接口用法_SQL注入',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656151,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 788,
#     'from': 'vupload',
#     'page': 299,
#     'part': '290_JDBC_PreparedStatement用法_占位符_参数处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656199,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 929,
#     'from': 'vupload',
#     'page': 300,
#     'part': '291_JDBC_ResultSet结果集用法_游标原理_关闭连接问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656265,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 417,
#     'from': 'vupload',
#     'page': 301,
#     'part': '292_JDBC_批处理Batch_插入2万条数据的测试',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656293,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 952,
#     'from': 'vupload',
#     'page': 302,
#     'part': '293_JDBC_事务概念_ACID特点_隔离级别_提交commit_回滚rollback',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656360,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 758,
#     'from': 'vupload',
#     'page': 303,
#     'part': '294_JDBC_时间处理_Date_Time_Timestamp区别_随机日期生成',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656400,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 751,
#     'from': 'vupload',
#     'page': 304,
#     'part': '295_JDBC_时间操作_时间段和日期段查询',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656424,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 797,
#     'from': 'vupload',
#     'page': 305,
#     'part': '296_JDBC_CLOB文本大对象操作',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656471,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 631,
#     'from': 'vupload',
#     'page': 306,
#     'part': '297_JDBC_BLOB_二进制大对象的使用',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656512,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 987,
#     'from': 'vupload',
#     'page': 307,
#     'part': '298_JDBC_代码总结_简单封装_资源文件properties处理连接信息',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656547,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1196,
#     'from': 'vupload',
#     'page': 308,
#     'part': '299_JDBC_ORM原理_使用Object数组存储一条记录',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656585,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 684,
#     'from': 'vupload',
#     'page': 309,
#     'part': '300_JDBC_ORM原理_Map封装一条记录_Map和List封装多条记录',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656625,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 607,
#     'from': 'vupload',
#     'page': 310,
#     'part': '301_JDBC_ORM原理_使用javabean对象封装一条记录',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656655,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 845,
#     'from': 'vupload',
#     'page': 311,
#     'part': '302_【手写SORM框架】_思想介绍_架构介绍',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656679,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1866,
#     'from': 'vupload',
#     'page': 312,
#     'part': '303_【手写SORM框架】_架构设计_接口设计',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656750,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1487,
#     'from': 'vupload',
#     'page': 313,
#     'part': '304_【手写SORM框架】_DBManager_配置信息_获取表结构_TableContext处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656790,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 483,
#     'from': 'vupload',
#     'page': 314,
#     'part': '305_【手写SORM框架】_mysql数据类型转化器_MySqlTypeConvertor',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656808,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1263,
#     'from': 'vupload',
#     'page': 315,
#     'part': '306_【手写SORM框架】_根据表信息生成JAVA类源代码_1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656884,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 933,
#     'from': 'vupload',
#     'page': 316,
#     'part': '307_【手写SORM框架】_根据表结构生成JAVA类源代码_2',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90656958,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1249,
#     'from': 'vupload',
#     'page': 317,
#     'part': '308_【手写SORM框架】_同步表结构到po包_生成所有java类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657050,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1312,
#     'from': 'vupload',
#     'page': 318,
#     'part': '309_【手写SORM框架】_delete方法的实现_class和表结构对应处理',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657129,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 433,
#     'from': 'vupload',
#     'page': 319,
#     'part': '310_【手写SORM框架】_executeDML方法_测试delete方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657147,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 957,
#     'from': 'vupload',
#     'page': 320,
#     'part': '311_【手写SORM框架】_插入数据_insert方法的实现',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657178,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 603,
#     'from': 'vupload',
#     'page': 321,
#     'part': '312_【手写SORM框架】_修改数据_update方法实现',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657192,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1162,
#     'from': 'vupload',
#     'page': 322,
#     'part': '313_【手写SORM框架】_查询多行记录封装成List和Javabean_queryRows方法',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657233,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 646,
#     'from': 'vupload',
#     'page': 323,
#     'part': '314_【手写SORM框架】_联表查询测试_VO值对象封装查询结果',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657262,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 508,
#     'from': 'vupload',
#     'page': 324,
#     'part': '315_【手写SORM框架】_其他查询方式_一行记录_一个对象',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657309,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1734,
#     'from': 'vupload',
#     'page': 325,
#     'part': '316_【手写SORM框架】_模板方法模式_回调方法优化Query类',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657382,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1052,
#     'from': 'vupload',
#     'page': 326,
#     'part': '317_【手写SORM框架】_工厂模式QueryFactory_克隆模式',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657409,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1324,
#     'from': 'vupload',
#     'page': 327,
#     'part': '318_【手写SORM框架】_连接池原理_手写连接池',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657478,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 730,
#     'from': 'vupload',
#     'page': 328,
#     'part': '319_【手写SORM框架】_连接池效率测试',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657509,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 665,
#     'from': 'vupload',
#     'page': 329,
#     'part': '320_【手写SORM框架】_jar包和API文档生成',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657535,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 504,
#     'from': 'vupload',
#     'page': 330,
#     'part': '321_【手写SORM框架】_使用说明_配置和启动过程_1',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657553,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1877,
#     'from': 'vupload',
#     'page': 331,
#     'part': '322_【手写SORM框架】_使用说明_bug修复_2',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657600,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1345,
#     'from': 'vupload',
#     'page': 332,
#     'part': '323_为什么需要学编程，什么样的人可以做程序员',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657632,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1050,
#     'from': 'vupload',
#     'page': 333,
#     'part': '324_流行的编程语言，应该怎么选择',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657648,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 718,
#     'from': 'vupload',
#     'page': 334,
#     'part': '325_本行不行，我可以转行到IT开发吗',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657658,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 815,
#     'from': 'vupload',
#     'page': 335,
#     'part': '326_程序员不是青春饭，程序员迈向百万年薪之路',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657676,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1084,
#     'from': 'vupload',
#     'page': 336,
#     'part': '327_零基础学员学习JAVA的秘诀',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657694,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 749,
#     'from': 'vupload',
#     'page': 337,
#     'part': '328_十分钟秒懂编程，程序就是现实逻辑的表达',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657708,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 766,
#     'from': 'vupload',
#     'page': 338,
#     'part': '329_表格思想_理解数据库存储数据',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657719,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 626,
#     'from': 'vupload',
#     'page': 339,
#     'part': '330_表格思想_理解JAVA类和对象',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657732,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 399,
#     'from': 'vupload',
#     'page': 340,
#     'part': '331_表格思想_理解XML文档',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657747,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1019,
#     'from': 'vupload',
#     'page': 341,
#     'part': '332_写出一份吸引面试官的简历(六大要素)',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657804,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 985,
#     'from': 'vupload',
#     'page': 342,
#     'part': '333_面试前，三大步让你秒杀90%竞争者',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657816,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1213,
#     'from': 'vupload',
#     'page': 343,
#     'part': '334_面试中，十大要点吸引面试官',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657829,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 422,
#     'from': 'vupload',
#     'page': 344,
#     'part': '335_技术面试中，不该问的4个问题',
#     'vid': '',
#     'weblink': ''},
#    {'cid': 90657836,
#     'dimension': {'height': 1080, 'rotate': 0, 'width': 1920},
#     'duration': 1291,
#     'from': 'vupload',
#     'page': 345,
#     'part': '336_职场成功的核武器_7A+软实力理论',
#     'vid': '',
#     'weblink': ''}],
#   'pic': 'http://i2.hdslb.com/bfs/archive/8692211e9a756bab2ec31086679ae7664ff1c82b.jpg',
#   'pubdate': 1534212746,
#   'rights': {'autoplay': 1,
#    'bp': 0,
#    'download': 1,
#    'elec': 0,
#    'hd5': 0,
#    'is_cooperation': 0,
#    'movie': 0,
#    'no_reprint': 0,
#    'pay': 0,
#    'ugc_pay': 0,
#    'ugc_pay_preview': 0},
#   'stat': {'aid': 29306544,
#    'coin': '--',
#    'danmaku': '--',
#    'dislike': 0,
#    'favorite': '--',
#    'his_rank': 0,
#    'like': '--',
#    'now_rank': 0,
#    'reply': 1396,
#    'share': '--',
#    'view': '--'},
#   'state': 0,
#   'subtitle': {'allow_submit': True, 'list': []},
#   'tid': 39,
#   'title': '【尚学堂】Java300集2019版--高淇',
#   'tname': '演讲• 公开课',
#   'videos': 345}}

# %%
playinfo_text = match1(html_content, r'__playinfo__=(.*?)</script><script>')
playinfo_text
playinfo = json.loads(playinfo_text) if playinfo_text else None
playinfo
# Out:
# {'code': 0,
#  'data': {'accept_description': ['高清 1080P', '高清 720P', '清晰 480P', '流畅 360P'],
#   'accept_format': 'flv,flv720,flv480,flv360',
#   'accept_quality': [80, 64, 32, 16],
#   'dash': {'audio': [{'SegmentBase': {'Initialization': '0-919',
#      'base_url': 'http://cn-gdfs2-cc-acache-01.acgvideo.com/upgcxcode/88/49/94024988/94024988-1-30080.m4s?e=ig8euxZM2rNcNbdlhoNvNC8BqJIzNbfqXBvEqxTEto8BTrNvN0GvT90W5JZMkX_YN0MvXg8gNEVEuxTEto8i8o859r1qXg8xNEVE5XREto8GuFGv2U7SuxI72X6fTr859r1qXg8gNEVE5XREto8z5JZC2X2gkX5L5F1eTX1jkXlsTXHeux_f2o859IB_&deadline=1559059654&gen=playurl&nbs=1&oi=3698564895&os=acache&platform=pc&trid=b217214297764c31b65f755ebfcdc792&uipk=5&upsig=bc5781e7a01485234895db0a1a4a130c&uparams=e,deadline,gen,nbs,oi,os,platform,trid,uipk',
#      'codecid': 7,
#      'codecs': 'avc1.640028',
#      'frameRate': '16000/528',
#      'frame_rate': '16000/528',
#      'height': 1080,
#      'id': 80,
#      'mimeType': 'video/mp4',
#      'mime_type': 'video/mp4',
#      'sar': '405:406',
#      'segment_base': {'index_range': '997-1208', 'initialization': '0-996'},
#      'startWithSap': 1,
#      'start_with_sap': 1,
#      'width': 1624}]},
#   'format': 'flv480',
#   'from': 'local',
#   'message': '',
#   'quality': 32,
#   'result': 'suee',
#   'seek_param': 'start',
#   'seek_type': 'offset',
#   'timelength': 74923,
#   'video_codecid': 7},
#  'message': '0',
#  'session': '7b9fa9cc0649165a87e7f2d561413c33',
#  'ttl': 1,
#  'videoFrame': {}}

# %%
pn = initial_state['videoData']['videos']
pn
# Out:
# 345

# %%
title = initial_state['videoData']['title']
title
# Out:
# '【尚学堂】Java300集2019版--高淇'

# %%
currentQuality = playinfo['data']['quality']
currentQuality
# Out:
# 32

# %%
playinfo['data']['accept_quality']
# Out:
# [80, 64, 32, 16]

# %%
qualityIDs = []
for i in playinfo['data']['accept_quality']:
    if i in (116,80,74,64,48,32,16):#我们只对stream_types里面有的视频质量进行下载
        qualityIDs.append(i)
qualityIDs
# Out:
# [80, 64, 32, 16]

# %%
acceptQualitys = [stream_qualities[id]['desc'] for id in qualityIDs]
acceptQualitys
# Out:
# ['高清 1080P', '高清 720P', '清晰 480P', '流畅 360P']

# %%
p = int(match1(url, r'[\?&]p=(\d+)') or match1(url, r'/index_(\d+)') or '1')
cid = initial_state['videoData']['pages'][p - 1]['cid']
# 请求弹幕文件并解码
response = requests.get('http://comment.bilibili.com/%s.xml' % cid,headers=bilibili_headers())
danmaku = response.content.decode()
danmaku
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><i><chatserver>chat.bilibili.com</chatserver><chatid>94024988</chatid><mission>0</mission><maxlimit>500</maxlimit><state>0</state><real_name>0</real_name><source>k-v</source><d p="70.66200,1,25,16777215,1558963059,0,e34a75a,16683307835064322">我知道你们都有在看</d><d p="74.90000,1,25,16777215,1558964054,0,9e41cd2c,16683829356396548">有</d><d p="15.41100,1,25,16777215,1558966112,0,b2033062,16684908705480704">？？？？怎么有女声了，看着看着就更新了，真棒</d><d p="34.50900,1,25,16777215,1559002261,0,7fc278ea,16703860810711042">吓我一跳</d><d p="22.44900,1,25,16777215,1559002249,0,7fc278ea,16703854543372290">？？？？！</d><d p="49.61600,1,25,16777215,1559007623,0,9806d51,16706672332898304">................</d><d p="74.01900,1,25,16777215,1559023895,0,70a60ff3,16715203664150530">我...............该说啥好</d><d p="54.81200,1,25,16777215,1559029929,0,b8ce7efb,16718366956847106">，，，，，，，，，，，，</d><d p="30.28000,1,25,16777215,1559035937,0,785dc0e9,16721517203161092">声音真甜</d><d p="60.63500,1,25,16777215,1559038389,0,a06e65c3,16722802243010562">变味了</d></i>'

# %%
format_id = stream_qualities[currentQuality]['id']
container = stream_qualities[currentQuality]['container'].lower()
print(container)
desc = stream_qualities[currentQuality]['desc']
print(desc)
print(format_id)
# Out:
# flv
# 清晰 480P
# flv480

# %%
streams = {}
if 'durl' in playinfo['data']:
    src, size = [], 0
    for durl in playinfo['data']['durl']:
        src.append(durl['url'])
        size += durl['size']
    streams[format_id] = {'container': container, 'quality': desc, 'size': size, 'src': src}
streams
# Out:
# {}

# %%
initial_state['videoData']['pages']
# Out:
# [{'cid': 31632396,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 5859,
#   'from': 'vupload',
#   'page': 1,
#   'part': '视觉SLAM十四讲ch1~2',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632397,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 7417,
#   'from': 'vupload',
#   'page': 2,
#   'part': '视觉SLAM十四讲ch3',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632398,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 5641,
#   'from': 'vupload',
#   'page': 3,
#   'part': '视觉SLAM十四讲ch4',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632399,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 4556,
#   'from': 'vupload',
#   'page': 4,
#   'part': '视觉SLAM十四讲ch5',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632400,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 5596,
#   'from': 'vupload',
#   'page': 5,
#   'part': '视觉SLAM十四讲ch6',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632401,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 5483,
#   'from': 'vupload',
#   'page': 6,
#   'part': '视觉SLAM十四讲ch7_1',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632402,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 4128,
#   'from': 'vupload',
#   'page': 7,
#   'part': '视觉SLAM十四讲ch7_2',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632403,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 4594,
#   'from': 'vupload',
#   'page': 8,
#   'part': '视觉SLAM十四讲ch8',
#   'vid': '',
#   'weblink': ''},
#  {'cid': 31632404,
#   'dimension': {'height': 0, 'rotate': 0, 'width': 0},
#   'duration': 5492,
#   'from': 'vupload',
#   'page': 9,
#   'part': '视觉SLAM十四讲ch10',
#   'vid': '',
#   'weblink': ''}]
